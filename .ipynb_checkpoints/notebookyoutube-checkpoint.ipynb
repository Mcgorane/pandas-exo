# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline
# %reload_ext autoreload
# %autoreload

# %%
url = 'USvideos.csv'
youtube_df = pd.read_csv(url)
youtube_df.head()
# Out:
#       video_id trending_date  \
# 0  2kyS6SvSYSE      17.14.11
# 1  1ZAPwfrtAFY      17.14.11
# 2  5qpjK5DgCt4      17.14.11
# 3  puqaWrEC7tY      17.14.11
# 4  d380meD0W0M      17.14.11
#
#                                                title          channel_title  \
# 0                 WE WANT TO TALK ABOUT OUR MARRIAGE           CaseyNeistat
# 1  The Trump Presidency: Last Week Tonight with J...        LastWeekTonight
# 2  Racist Superman | Rudy Mancuso, King Bach & Le...           Rudy Mancuso
# 3                   Nickelback Lyrics: Real or Fake?  Good Mythical Morning
# 4                           I Dare You: GOING BALD!?               nigahiga
#
#    category_id              publish_time  \
# 0           22  2017-11-13T17:13:01.000Z
# 1           24  2017-11-13T07:30:00.000Z
# 2           23  2017-11-12T19:05:24.000Z
# 3           24  2017-11-13T11:00:04.000Z
# 4           24  2017-11-12T18:01:41.000Z
#
# ...

# %%
most_viewed_youtubers = youtube_df.groupby("channel_title").views.sum().sort_values(ascending=False).head()
most_viewed_youtubers = pd.DataFrame(data=most_viewed_youtubers)
most_viewed_youtubers.reset_index(inplace=True)

def to_millions(number):
    millions = number / 1000000
    return millions
    

for i, view in enumerate(most_viewed_youtubers.views):
    most_viewed_youtubers.views[i] = to_millions(view)
    

display(most_viewed_youtubers)
# Out:
# <ipython-input-4-f234f67229df>:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   most_viewed_youtubers.views[i] = to_millions(view)
#           channel_title  views
# 0   ChildishGambinoVEVO   3758
# 1               ibighit   2235
# 2          Dude Perfect   1870
# 3  Marvel Entertainment   1808
# 4      ArianaGrandeVevo   1576

# %%
sns.set_style("darkgrid")
sns.set(font_scale=1.1)
f = plt.figure(figsize=(10,5))
sns.barplot(x='channel_title', y='views', data = most_viewed_youtubers)

# %%
# Pie chart, where the slices will be ordered and plotted counter-clockwise:
labels = 'Likes', 'Dislikes'
sizes = [youtube_df.likes.sum(), youtube_df.dislikes.sum()]

fig1, ax1 = plt.subplots(figsize=(10,10))
ax1.pie(sizes, labels=labels, autopct='%1.1f%%', startangle=90, textprops=dict(fontsize=14), )
ax1.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.

plt.show()

# %%
trending_date = youtube_df.groupby('trending_date').sum()
display(trending_date.head(30))
# Out:
#                category_id      views     likes  dislikes  comment_count  \
# trending_date
# 17.01.12              4138  232922521  10261408    273292        1562812
# 17.02.12              3931  216493881   9111105    246855        1022963
# 17.03.12              3896  252269204   9874303    274121        1044691
# 17.04.12              3950  284933560  10405210    308329        1033652
# 17.05.12              3937  315863007  10993189    356188        1081209
# 17.06.12              3942  336281463  11734154    352725        1175419
# 17.07.12              3986  385936747  13396888    807949        1677068
# 17.08.12              4180  395720361  13560573   1206275        1833551
# 17.09.12              4115  294591913  10213968   1408274        1814468
# 17.10.12              4137  327000962  10004971   1645570        1682519
# 17.11.12              4160  374007988  10892272   1803280        1852339
# 17.12.12              4222  356733762  11207459   1916981        2055048
# ...
